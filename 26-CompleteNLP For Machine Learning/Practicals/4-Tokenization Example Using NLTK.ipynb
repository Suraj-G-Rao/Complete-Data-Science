# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\anaconda\envs\flenv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in d:\anaconda\envs\flenv\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\anaconda\envs\flenv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in d:\anaconda\envs\flenv\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in d:\anaconda\envs\flenv\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raosu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.data.clear_cache()
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raosu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.data.path.append('C:/Users/raosu/AppData/Roaming/nltk_data')  # Or wherever your nltk_data is stored
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raosu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')  # If needed
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raosu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\raosu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello!
# Welcome to Krish Naik's NLP Tutorials.
# Please do watch the entire course to become an expert in NLP.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', '!']
# ['Welcome', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', 'to', 'become', 'an', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'Welcome',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']
