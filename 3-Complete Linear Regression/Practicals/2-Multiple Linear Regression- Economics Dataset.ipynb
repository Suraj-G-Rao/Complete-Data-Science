# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index=pd.read_csv("economic_index.csv")

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
#drop unneccessary columns
df_index.drop(columns=["Unnamed: 0","year","month"],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
##check null values
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## Lets do some viualization
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
## Visualiza the datapoints more closely
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='r')
plt.xlabel("Interest rate")
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
##independent and dependent features
X=df_index.iloc[:,:-1]
y=df_index.iloc[:,-1]

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
sns.regplot(x=df_index['index_price'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## cross validation
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',
                                cv=3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162388)

# %%
## prediction
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([1204.22770398,  821.65051903, 1406.51300368,  857.70889608,
#         994.90992298, 1168.16932693])

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 5793.762887712569
# 59.935781523235484
# 76.11677139574805

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
#display adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# 0.8278978091457145
# 0.7131630152428576

# %% [markdown]
# ## Assumptions

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -45.227704
# 16    149.349481
# 0      57.486996
# 18     26.291104
# 11     80.090077
# 9      -1.169327
# Name: index_price, dtype: float64

# %%
## Plot this residuals
sns.displot(residuals,kind='kde')

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(y_pred,residuals)

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from statsmodels) (2.0.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raosu\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\raosu\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 2.4 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/9.8 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.8 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.8 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.8 MB 825.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.8 MB 825.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.8 MB 825.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.8 MB 825.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.8 MB 825.2 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.8 MB 568.6 kB/s eta 0:00:15
#    ------ --------------------------------- 1.6/9.8 MB 399.5 kB/s eta 0:00:21
#    ------ --------------------------------- 1.6/9.8 MB 399.5 kB/s eta 0:00:21
#    ------ --------------------------------- 1.6/9.8 MB 399.5 kB/s eta 0:00:21
#    ------ --------------------------------- 1.6/9.8 MB 399.5 kB/s eta 0:00:21
#    ------ --------------------------------- 1.6/9.8 MB 399.5 kB/s eta 0:00:21
#    ------- -------------------------------- 1.8/9.8 MB 370.1 kB/s eta 0:00:22
#    ------- -------------------------------- 1.8/9.8 MB 370.1 kB/s eta 0:00:22
#    -------- ------------------------------- 2.1/9.8 MB 402.2 kB/s eta 0:00:20
#    -------- ------------------------------- 2.1/9.8 MB 402.2 kB/s eta 0:00:20
#    --------- ------------------------------ 2.4/9.8 MB 409.2 kB/s eta 0:00:19
#    --------- ------------------------------ 2.4/9.8 MB 409.2 kB/s eta 0:00:19
#    --------- ------------------------------ 2.4/9.8 MB 409.2 kB/s eta 0:00:19
#    --------- ------------------------------ 2.4/9.8 MB 409.2 kB/s eta 0:00:19
#    ---------- ----------------------------- 2.6/9.8 MB 393.2 kB/s eta 0:00:19
#    ---------- ----------------------------- 2.6/9.8 MB 393.2 kB/s eta 0:00:19
#    ---------- ----------------------------- 2.6/9.8 MB 393.2 kB/s eta 0:00:19
#    ---------- ----------------------------- 2.6/9.8 MB 393.2 kB/s eta 0:00:19
#    ----------- ---------------------------- 2.9/9.8 MB 388.4 kB/s eta 0:00:18
#    ----------- ---------------------------- 2
kB/s eta 0:00:11
#    ------------------------- -------------- 6.3/9.8 MB 351.4 kB/s eta 0:00:11
#    ------------------------- -------------- 6.3/9.8 MB 351.4 kB/s eta 0:00:11
#    ------------------------- -------------- 6.3/9.8 MB 351.4 kB/s eta 0:00:11
#    -------------------------- ------------- 6.6/9.8 MB 357.0 kB/s eta 0:00:10
#    --------------------------- ------------ 6.8/9.8 MB 364.4 kB/s eta 0:00:09
#    --------------------------- ------------ 6.8/9.8 MB 364.4 kB/s eta 0:00:09
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ---------------------------- ----------- 7.1/9.8 MB 370.9 kB/s eta 0:00:08
#    ----------------------------- ---------- 7.3/9.8 MB 360.9 kB/s eta 0:00:07
#    ----------------------------- ---------- 7.3/9.8 MB 360.9 kB/s eta 0:00:07
#    ----------------------------- ---------- 7.3/9.8 MB 360.9 kB/s eta 0:00:07
#    ----------------------------- ---------- 7.3/9.8 MB 360.9 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    ------------------------------ --------- 7.6/9.8 MB 357.5 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    -------------------------------- ------- 7.9/9.8 MB 322.4 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    --------------------------------- ------ 8.1/9.8 MB 277.9 kB/s eta 0:00:07
#    ---------------------------------- ----- 8.4/9.8 MB 241.5 kB/s eta 0:00:06
#    ---------------------------------- ----- 8.4/9.8 MB 241.5 kB/s eta 0:00:06
#    ---------------------------------- ----- 8.4/9.8 MB 241.5 kB/s eta 0:00:06
#    ---------------------------------- ----- 8.4/9.8 MB 241.5 kB/s eta 0:00:06
#    ---------------------------------- ----- 8.4/9.8 MB 241.5 kB/s eta 0:00:06
#    ----------------------------------- ---- 8.7/9.8 MB 244.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 8.7/9.8 MB 244.2 kB/s eta 0:00:05
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------ --- 8.9/9.8 MB 249.1 kB/s eta 0:00:04
#    ------------------------------------- -- 9.2/9.8 MB 245.3 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.8 MB 245.3 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.8 MB 245.3 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.8 MB 245.3 kB/s eta 0:00:03
#    ------------------------------------- -- 9.2/9.8 MB 245.3 kB/s eta 0:00:03
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.8 MB 235.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 228.0 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 228.0 kB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 225.5 kB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2

# %%
## OLS Linear Regression
import statsmodels.api as sm
model=sm.OLS(y_train,X_train).fit()

# %%
model.summary()
# Out:
# C:\Users\raosu\AppData\Roaming\Python\Python312\site-packages\scipy\stats\_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):                       0.754
# Time:                        21:25:25   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# Df Residuals:                      16   BIC:                                      307.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            88.2728    658.295      0.134      0.895   -1307.250    1483.796
# x2          -116.2572    658.295     -0.177      0.862   -1511.780    1279.266
# ==============================================================================
# Omnibus:                        0.598   Durbin-Watson:                   0.007
# Prob(Omnibus):                  0.741   Jarque-Bera (JB):                0.567
# Skew:                          -0.361   Prob(JB):                        0.753
# Kurtosis:                       2.517   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(regression.coef_)
# Out:
# [  88.27275507 -116.25716066]
